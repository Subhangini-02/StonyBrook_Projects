# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score,precision_score,recall_score
from sklearn.metrics import classification_report

# %%
dataset = pd.read_csv('Indian Liver Patient Dataset (ILPD).csv')

# %%
dataset
# Out:
#      65 Female   0.7  0.1  187  16   18  6.8  3.3   0.9  1
# 0    62   Male  10.9  5.5  699  64  100  7.5  3.2  0.74  1
# 1    62   Male   7.3  4.1  490  60   68  7.0  3.3  0.89  1
# 2    58   Male   1.0  0.4  182  14   20  6.8  3.4  1.00  1
# 3    72   Male   3.9  2.0  195  27   59  7.3  2.4  0.40  1
# 4    46   Male   1.8  0.7  208  19   14  7.6  4.4  1.30  1
# ..   ..    ...   ...  ...  ...  ..  ...  ...  ...   ... ..
# 577  60   Male   0.5  0.1  500  20   34  5.9  1.6  0.37  2
# 578  40   Male   0.6  0.1   98  35   31  6.0  3.2  1.10  1
# 579  52   Male   0.8  0.2  245  48   49  6.4  3.2  1.00  1
# 580  31   Male   1.3  0.5  184  29   32  6.8  3.4  1.00  1
# 581  38   Male   1.0  0.3  216  21   24  7.3  4.4  1.50  2
#
# [582 rows x 11 columns]

# %%
Split=dataset.values
X = Split[:,2:4]
y = Split[:, 4]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5, random_state = 0)

# %%
sc = StandardScaler()
# print(sc)
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
# print(X_test)
# print(X_train)

# %%
y_train
# Out:
# array([140, 650, 664, 272, 194, 208, 232, 282, 158, 206, 259, 145, 405,
#        160, 230, 165, 168, 176, 166, 168, 282, 1420, 168, 218, 168, 230,
#        185, 152, 178, 186, 182, 265, 188, 392, 250, 205, 558, 270, 1580,
#        375, 1550, 182, 1020, 215, 950, 580, 805, 198, 162, 282, 220, 859,
#        148, 163, 210, 850, 901, 2110, 178, 410, 238, 174, 275, 150, 198,
#        158, 218, 202, 390, 450, 175, 125, 206, 190, 145, 234, 145, 560,
#        190, 265, 185, 196, 175, 290, 289, 128, 110, 180, 196, 130, 310,
#        380, 401, 145, 352, 310, 92, 116, 108, 314, 100, 268, 163, 360,
#        245, 239, 289, 172, 159, 280, 194, 400, 512, 145, 179, 292, 358,
#        220, 160, 180, 171, 915, 194, 212, 192, 145, 239, 174, 188, 258,
#        290, 592, 282, 599, 237, 280, 206, 168, 289, 257, 180, 260, 178,
#        165, 190, 258, 188, 238, 182, 186, 190, 505, 621, 380, 216, 171,
#        298, 498, 509, 159, 224, 610, 211, 159, 189, 235, 183, 186, 282,
# ...

# %%
model=SVC(kernel='linear', C= 1)
model.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-3368c672d7f0> in <module>
#       1 model=SVC()
# ----> 2 model.fit(X_train,y_train)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     197             )
#     198
# --> 199         y = self._validate_targets(y)
#     200
#     201         sample_weight = np.asarray(
#
# /usr/local/lib/python3.7/dist-packages/sklearn/svm/_base.py in _validate_targets(self, y)
#     714     def _validate_targets(self, y):
#     715         y_ = column_or_1d(y, warn=True)
# --> 716         check_classification_targets(y)
#     717         cls, y = np.unique(y_, return_inverse=True)
#     718         self.class_weight_ = compute_class_weight(self.class_weight, classes=cls, y=y_)
#
# ...

# %%
y_predict = model.predict(X_test)
print("Accuracy of the data set is: %.2f" % accuracy_score(y_test,y_predict))
print("Data Sensitivity: %.2f" % precision_score(y_test,y_predict))
print("Data Specificity: %.2f" % recall_score(y_test,y_predict))

# %%
cm = confusion_matrix(y_test, y_predict)
# print(classification_report(y_test, y_predict))
# print(cm)
# TP = cm[1,1]
# TN = cm[0,0]
# FP = cm[1,0]
# FN = cm[0,1]

# %%
# cm = confusion_matrix(y_test, y_predict)
# print(cm)

# print('\nTrue Positives(TP) = ', cm[1,1])

# print('\nTrue Negatives(TN) = ', cm[0,0])

# print('\nFalse Positives(FP) = ', cm[1,0])

# print('\nFalse Negatives(FN) = ', cm[0,1])
# # accuracy_score(y_test,y_predict)
# classification_accuracy = (TP + TN) / float(TP + TN + FP + FN)

# print('Classification accuracy : {0:0.4f}'.format(classification_accuracy))
# specificity = TN / (TN + FP)
# Sensitivity = TP / float(TP + FN)

# print('Sensitivity : {0:0.4f}'.format(Sensitivity ))
# print('Specificity : {0:0.4f}'.format(specificity))

# %%
# from matplotlib.colors import ListedColormap
# X_set, y_set = X_test, y_test
# X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
#                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
# plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#              alpha = 0.75, cmap = ListedColormap(('red', 'green')))
# plt.xlim(X1.min(), X1.max())
# plt.ylim(X2.min(), X2.max())
# for i, j in enumerate(np.unique(y_set)):
#     plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
#                 c = ListedColormap(('red', 'green'))(i), label = j)
# plt.title('SVM (Test set)')
# plt.xlabel('Age')
# plt.ylabel('Estimated Salary')
# plt.legend()
# plt.show()
